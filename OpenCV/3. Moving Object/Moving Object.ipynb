# %%
import cv2
import time
import imutils

cam = cv2.VideoCapture(0)
time.sleep(1)

firstFrame=None
area = 500
count = 0

while True:
    _,img = cam.read()
    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21, 21), 0)
    if firstFrame is None:
            firstFrame = gaussianImg
            continue
    imgDiff = cv2.absdiff(firstFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)
    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL,
            cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    for c in cnts:
            if cv2.contourArea(c) < area:
                    continue
            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            count+=1
            text = "Moving Object detected" +str(count)
    print(text)
    cv2.putText(img, text, (10, 20),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    cv2.imshow("cameraFeed",img)
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Moving Object detected3
# Moving Object detected6
# Moving Object detected9
# Moving Object detected12
# Moving Object detected13
# Moving Object detected14
# Moving Object detected15
# Moving Object detected18
# Moving Object detected21
# Moving Object detected24
# Moving Object detected27
# Moving Object detected30
# Moving Object detected33
# Moving Object detected36
# Moving Object detected38
# Moving Object detected39
# Moving Object detected40
# Moving Object detected41
# Moving Object detected42
# Moving Object detected44
# Moving Object detected46
# Moving Object detected48
# Moving Object detected50
# Moving Object detected51
# Moving Object detected52
# Moving Object detected53
# Moving Object detected56
# Moving Object detected59
# Moving Object detected62
# Moving Object detected65
# Moving Object detected68
# Moving Object detected71
# Moving Object detected74
# Moving Object detected78
# Moving Object detected82
# Moving Object detected86
# Moving Object detected90
# Moving Object detected94
# Moving Object detected98
# Moving Object detected102
# Moving Object detected105
# Moving Object detected108
# Moving Object detected111
# Moving Object detected114
# Moving Object detected117
# Moving Object detected120
# Moving Object detected123
# Moving Object detected126
# Moving Object detected129
# Moving Object detected131
# Moving Object detected133
# Moving Object detected135
# Moving Object detected137
# Moving Object detected140
# Moving Object detected143
# Moving Object detected146
# Moving Object detected149
# Moving Object detected152
# Moving Object detected155
# Moving Object detected158
# Moving Object detected161
# Moving Object detected164
# Moving Object detected168
# Moving Object detected172
# Moving Object detected178
# Moving Object detected184
# Moving Object detected191
# Moving Object detected198
# Moving Object detected204
# Moving Object detected210
# Moving Object detected216
# Moving Object detected222
# Moving Object detected228
# Moving Object detected232
# Moving Object detected236
# Moving Object detected241
# Moving Object detected246
# Moving Object detected251
# Moving Object detected255
# Moving Object detected259
# Moving Object detected263
# Moving Object detected267
# Moving Object detected271
# Moving Object detected274
# Moving Object detected277
# Moving Object detected281
# Moving Object detected285
# Moving Object detected287
# Moving Object detected289
# Moving Object detected291
# Moving Object detected293
# Moving Object detected296
# Moving Object detected299
# Moving Object detected304
# Moving Object detected309
# Moving Object detected313
# Moving Object detected317
# Moving Object detected321
# Moving Object detected326
# Moving Object detected331
# Moving Object detected335
# Moving Object detected339
# Moving Object detected346
# Moving Object detected353
# Moving Object detected359
# Moving Object detected365
# Moving Object detected371
# Moving Object detected375
# Moving Object detected379
# Moving Object detected383
# Moving Object detected387
# Moving Object detected391
# Moving Object detected395
# Moving Object detected399
# Moving Object detected403
# Moving Object detected407
# Moving Object detected411
# Moving Object detected415
# Moving Object detected419
# Moving Object detected424
# Moving Object detected429
# Moving Object detected436
# Moving Object detected443
# Moving Object detected451
# Moving Object detected459
# Moving Object detected466
# Moving Object detected473
# Moving Object detected480
# Moving Object detected487
# Moving Object detected494
# Moving Object detected501
# Moving Object detected507
# Moving Object detected514
# Moving Object detected521
# Moving Object detected529
# Moving Object detected537
# Moving Object detected543
# Moving Object detected549
# Moving Object detected556
# Moving Object detected562
# Moving Object detected568
# Moving Object detected574
# Moving Object detected580
# Moving Object detected585
# Moving Object detected590
# Moving Object detected593
# Moving Object detected596
# Moving Object detected599
# Moving Object detected603
# Moving Object detected607
# Moving Object detected610
# Moving Object detected613
# Moving Object detected615
# Moving Object detected617
# Moving Object detected619
# Moving Object detected621
# Moving Object detected623
# Moving Object detected627
# Moving Object detected631
# Moving Object detected636
# Moving Object detected641
# Moving Object detected645
# Moving Object detected649
# Moving Object detected653
# Moving Object detected657
# Moving Object detected662
# Moving Object detected667
# Moving Object detected672
# Moving Object detected677
# Moving Object detected682
# Moving Object detected687
# Moving Object detected692
# Moving Object detected695
# Moving Object detected698
# Moving Object detected700
# Moving Object detected702
# Moving Object detected704
# Moving Object detected706
# Moving Object detected708
# Moving Object detected710
# Moving Object detected712
# Moving Object detected714
# Moving Object detected715
# Moving Object detected716
# Moving Object detected717
# Moving Object detected718
# Moving Object detected719
# Moving Object detected720
# Moving Object detected721
# Moving Object detected722
# Moving Object detected723
# Moving Object detected724
# Moving Object detected725
# Moving Object detected726
# Moving Object detected727
# Moving Object detected728
# Moving Object detected729
# Moving Object detected730
# Moving Object detected731
# Moving Object detected732
# Moving Object detected733
# Moving Object detected734
# Moving Object detected735
# Moving Object detected736
# Moving Object detected737
# Moving Object detected738
# Moving Object detected739
# Moving Object detected740
# Moving Object detected741
# Moving Object detected742
# Moving Object detected744
# Moving Object detected746
# Moving Object detected748
# Moving Object detected750
# Moving Object detected752
# Moving Object detected754
# Moving Object detected756
# Moving Object detected758
# Moving Object detected760
# Moving Object detected762
# Moving Object detected764
# Moving Object detected766
# Moving Object detected768
# Moving Object detected770
# Moving Object detected772
# Moving Object detected774
# Moving Object detected776
# Moving Object detected778
# Moving Object detected780
# Moving Object detected782
# Moving Object detected784
# Moving Object detected786
# Moving Object detected788
# Moving Object detected790
# Moving Object detected792
# Moving Object detected794
# Moving Object detected796
# Moving Object detected798
# Moving Object detected800
# Moving Object detected802
# Moving Object detected804
# Moving Object detected806
# Moving Object detected808
# Moving Object detected810
# Moving Object detected812
# Moving Object detected814
# Moving Object detected816
# Moving Object detected818
# Moving Object detected820
# Moving Object detected822
# Moving Object detected824
# Moving Object detected826
# Moving Object detected828
# Moving Object detected830
# Moving Object detected832
# Moving Object detected834
# Moving Object detected836
# Moving Object detected838
# Moving Object detected840
# Moving Object detected842
# Moving Object detected844
# Moving Object detected846
# Moving Object detected848
# Moving Object detected850
# Moving Object detected852
# Moving Object detected854
# Moving Object detected856
# Moving Object detected858
# Moving Object detected860
# Moving Object detected862
# Moving Object detected864
# Moving Object detected866
# Moving Object detected869
# Moving Object detected872
# Moving Object detected875
# Moving Object detected878
# Moving Object detected881
# Moving Object detected884
# Moving Object detected887
# Moving Object detected892
# Moving Object detected897
# Moving Object detected900
# Moving Object detected902
# Moving Object detected904
# Moving Object detected906
# Moving Object detected908
# Moving Object detected910
# Moving Object detected912
# Moving Object detected914
# Moving Object detected917
# Moving Object detected920
# Moving Object detected923
# Moving Object detected926
# Moving Object detected929
# Moving Object detected932
# Moving Object detected935
# Moving Object detected938
# Moving Object detected943
# Moving Object detected948
# Moving Object detected953
# Moving Object detected958
# Moving Object detected963
# Moving Object detected968
# Moving Object detected973
# Moving Object detected978
# Moving Object detected983
# Moving Object detected987
# Moving Object detected991
# Moving Object detected994
# Moving Object detected998
# Moving Object detected1002
# Moving Object detected1004
# Moving Object detected1006
# Moving Object detected1010
# Moving Object detected1014
# Moving Object detected1017
# Moving Object detected1020
# Moving Object detected1023
# Moving Object detected1026
# Moving Object detected1029
# Moving Object detected1032
# Moving Object detected1035
# Moving Object detected1038
# Moving Object detected1041
# Moving Object detected1044
# Moving Object detected1047
# Moving Object detected1050
# Moving Object detected1053
# Moving Object detected1056
# Moving Object detected1059
# Moving Object detected1062
# Moving Object detected1065
# Moving Object detected1068
# Moving Object detected1072
# Moving Object detected1076
# Moving Object detected1080
# Moving Object detected1084
# Moving Object detected1088
# Moving Object detected1094
# Moving Object detected1100
# Moving Object detected1106
# Moving Object detected1112
# Moving Object detected1119
# Moving Object detected1126
# Moving Object detected1134
# Moving Object detected1142
# Moving Object detected1150
# Moving Object detected1158
# Moving Object detected1164
# Moving Object detected1170
# Moving Object detected1176
# Moving Object detected1182
# Moving Object detected1188
# Moving Object detected1194
# Moving Object detected1200
# Moving Object detected1206
# Moving Object detected1212
# Moving Object detected1218
# Moving Object detected1224
# Moving Object detected1230
# Moving Object detected1236
# Moving Object detected1242
# Moving Object detected1248
# Moving Object detected1254
# Moving Object detected1260
# Moving Object detected1266
# Moving Object detected1272
# Moving Object detected1278
# Moving Object detected1284
# Moving Object detected1290
# Moving Object detected1296
# Moving Object detected1302
# Moving Object detected1308
# Moving Object detected1314
# Moving Object detected1320
# Moving Object detected1326
# Moving Object detected1332
# Moving Object detected1338
# Moving Object detected1344
# Moving Object detected1350
# Moving Object detected1356
# Moving Object detected1362
# Moving Object detected1367
# Moving Object detected1372
# Moving Object detected1377
# Moving Object detected1382
# Moving Object detected1388
# Moving Object detected1395
# Moving Object detected1402
# Moving Object detected1409
# Moving Object detected1416
# Moving Object detected1423
# Moving Object detected1430
# Moving Object detected1437
# Moving Object detected1443
# Moving Object detected1449
# Moving Object detected1454
# Moving Object detected1459
# Moving Object detected1465
# Moving Object detected1471
# Moving Object detected1477
# Moving Object detected1483
# Moving Object detected1489
# Moving Object detected1495
# Moving Object detected1502
# Moving Object detected1510
# Moving Object detected1518
# Moving Object detected1525
# Moving Object detected1532
# Moving Object detected1540
# Moving Object detected1548
# Moving Object detected1556
# Moving Object detected1564
# Moving Object detected1571
# Moving Object detected1578
# Moving Object detected1585
# Moving Object detected1592
# Moving Object detected1599
# Moving Object detected1606
# Moving Object detected1613
# Moving Object detected1620
# Moving Object detected1627
# Moving Object detected1633
# Moving Object detected1640
# Moving Object detected1647
# Moving Object detected1653
# Moving Object detected1659
# Moving Object detected1666
# Moving Object detected1673
# Moving Object detected1680
# Moving Object detected1687
# Moving Object detected1694
# Moving Object detected1702
# Moving Object detected1710
# Moving Object detected1717
# Moving Object detected1724
# Moving Object detected1731
# Moving Object detected1738
# Moving Object detected1745
# Moving Object detected1752
# Moving Object detected1760
# Moving Object detected1768
# Moving Object detected1776
# Moving Object detected1784
# Moving Object detected1792
# Moving Object detected1800
# Moving Object detected1808
# Moving Object detected1816
# Moving Object detected1824
# Moving Object detected1832
# Moving Object detected1840
# Moving Object detected1848
# Moving Object detected1856
# Moving Object detected1864
# Moving Object detected1871
# Moving Object detected1878
# Moving Object detected1883
# Moving Object detected1888
# Moving Object detected1893
# Moving Object detected1898
# Moving Object detected1903
# Moving Object detected1908
# Moving Object detected1913
# Moving Object detected1918
# Moving Object detected1922
# Moving Object detected1926
# Moving Object detected1930
# Moving Object detected1935
# Moving Object detected1940
# Moving Object detected1945
# Moving Object detected1950
# Moving Object detected1957
# Moving Object detected1964
# Moving Object detected1971
# Moving Object detected1977
# Moving Object detected1983
# Moving Object detected1989
# Moving Object detected1995
# Moving Object detected2001
# Moving Object detected2007
# Moving Object detected2014
# Moving Object detected2021
# Moving Object detected2028
# Moving Object detected2034
# Moving Object detected2040
# Moving Object detected2047
# Moving Object detected2054
# Moving Object detected2060
# Moving Object detected2066
# Moving Object detected2073
# Moving Object detected2080
# Moving Object detected2087
# Moving Object detected2093
# Moving Object detected2099
# Moving Object detected2106
# Moving Object detected2113
# Moving Object detected2119
# Moving Object detected2125
# Moving Object detected2131
# Moving Object detected2137
# Moving Object detected2143
# Moving Object detected2148
# Moving Object detected2153
# Moving Object detected2159
# Moving Object detected2165
# Moving Object detected2168
# Moving Object detected2171
# Moving Object detected2173
# Moving Object detected2175
# Moving Object detected2177
# Moving Object detected2179
# Moving Object detected2181
# Moving Object detected2184
# Moving Object detected2187
# Moving Object detected2191
# Moving Object detected2195
# Moving Object detected2200
# Moving Object detected2205
# Moving Object detected2210
# Moving Object detected2216
# Moving Object detected2222
# Moving Object detected2227
# Moving Object detected2232
# Moving Object detected2237
# Moving Object detected2242
# Moving Object detected2247
# Moving Object detected2252
# Moving Object detected2257
# Moving Object detected2263
# Moving Object detected2269
# Moving Object detected2274
# Moving Object detected2279
# Moving Object detected2284
# Moving Object detected2289
# Moving Object detected2294
# Moving Object detected2299
# Moving Object detected2305
# Moving Object detected2311
# Moving Object detected2317
# Moving Object detected2322
# Moving Object detected2327
# Moving Object detected2333
# Moving Object detected2339
# Moving Object detected2345
# Moving Object detected2351
# Moving Object detected2357
# Moving Object detected2363
# Moving Object detected2369
# Moving Object detected2374
# Moving Object detected2379
# Moving Object detected2385
# Moving Object detected2391
# Moving Object detected2397
# Moving Object detected2403
# Moving Object detected2409
# Moving Object detected2415
# Moving Object detected2421
# Moving Object detected2427
# Moving Object detected2433
# Moving Object detected2439
# Moving Object detected2445
# Moving Object detected2451
# Moving Object detected2457
# Moving Object detected2463
# Moving Object detected2469
# Moving Object detected2475
# Moving Object detected2481
# Moving Object detected2487
# Moving Object detected2491
# Moving Object detected2495
# Moving Object detected2499
# Moving Object detected2503
# Moving Object detected2507
# Moving Object detected2511
# Moving Object detected2515
# Moving Object detected2520
# Moving Object detected2526
# Moving Object detected2532
# Moving Object detected2538
# Moving Object detected2544
# Moving Object detected2549
# Moving Object detected2554
# Moving Object detected2559
# Moving Object detected2565
# Moving Object detected2572
# Moving Object detected2579
# Moving Object detected2582
# Moving Object detected2585
# Moving Object detected2588
# Moving Object detected2592
# Moving Object detected2596
# Moving Object detected2600
# Moving Object detected2604
# Moving Object detected2608
# Moving Object detected2612
# Moving Object detected2616
# Moving Object detected2620
# Moving Object detected2624
# Moving Object detected2628
# Moving Object detected2632
# Moving Object detected2636
# Moving Object detected2640
# Moving Object detected2642
# Moving Object detected2644
# Moving Object detected2646
# Moving Object detected2648
# Moving Object detected2650
# Moving Object detected2652
# Moving Object detected2654
# Moving Object detected2656
# Moving Object detected2658
# Moving Object detected2660
# Moving Object detected2662
# Moving Object detected2664
# Moving Object detected2666
# Moving Object detected2668
# Moving Object detected2670
# Moving Object detected2672
# Moving Object detected2674
# Moving Object detected2676
# Moving Object detected2678
# Moving Object detected2680
# Moving Object detected2682
# Moving Object detected2684
# Moving Object detected2686
# Moving Object detected2688
# Moving Object detected2690
# Moving Object detected2692
# Moving Object detected2694
# Moving Object detected2696
# Moving Object detected2698
# Moving Object detected2700
# Moving Object detected2702
# Moving Object detected2704
# Moving Object detected2706
# Moving Object detected2708
# Moving Object detected2710
# Moving Object detected2712
# Moving Object detected2714
# Moving Object detected2716
# Moving Object detected2718
# Moving Object detected2720
# Moving Object detected2722
# Moving Object detected2724
# Moving Object detected2726
# Moving Object detected2728
# Moving Object detected2730
# Moving Object detected2732
# Moving Object detected2734
# Moving Object detected2736
# Moving Object detected2738
# Moving Object detected2740
# Moving Object detected2742
# Moving Object detected2744
# Moving Object detected2746
# Moving Object detected2748
# Moving Object detected2750
# Moving Object detected2752
# Moving Object detected2754
# Moving Object detected2756
# Moving Object detected2758
# Moving Object detected2760
# Moving Object detected2762
# Moving Object detected2764
# Moving Object detected2766
# Moving Object detected2768
# Moving Object detected2770
# Moving Object detected2772
# Moving Object detected2774
# Moving Object detected2776
# Moving Object detected2778
# Moving Object detected2780
# Moving Object detected2782
# Moving Object detected2784
# Moving Object detected2786
# Moving Object detected2788
# Moving Object detected2790
# Moving Object detected2792
# Moving Object detected2794
# Moving Object detected2796
# Moving Object detected2798
# Moving Object detected2800
# Moving Object detected2802
# Moving Object detected2804
# Moving Object detected2806
# Moving Object detected2808
# Moving Object detected2810
# Moving Object detected2812
# Moving Object detected2814
# Moving Object detected2816
# Moving Object detected2818
# Moving Object detected2820
# Moving Object detected2822
# Moving Object detected2824
# Moving Object detected2826
# Moving Object detected2828
# Moving Object detected2830
# Moving Object detected2832
# Moving Object detected2834
# Moving Object detected2836
# Moving Object detected2838
# Moving Object detected2840
# Moving Object detected2842
# Moving Object detected2844
# Moving Object detected2846
# Moving Object detected2848
# Moving Object detected2850
# Moving Object detected2852
# Moving Object detected2854
# Moving Object detected2856
# Moving Object detected2858
# Moving Object detected2860
# Moving Object detected2862
# Moving Object detected2864
# Moving Object detected2866
# Moving Object detected2868
# Moving Object detected2870
# Moving Object detected2872
# Moving Object detected2874
# Moving Object detected2876
# Moving Object detected2878
# Moving Object detected2880
# Moving Object detected2882
# Moving Object detected2884
# Moving Object detected2886
# Moving Object detected2888
# Moving Object detected2890
# Moving Object detected2892
# Moving Object detected2894
# Moving Object detected2896
# Moving Object detected2898
# Moving Object detected2900
# Moving Object detected2902
# Moving Object detected2904
# Moving Object detected2906
# Moving Object detected2908
# Moving Object detected2910
# Moving Object detected2912
# Moving Object detected2914
# Moving Object detected2916
# Moving Object detected2918
# Moving Object detected2920
# Moving Object detected2922
# Moving Object detected2924
# Moving Object detected2926
# Moving Object detected2928
# Moving Object detected2930
# Moving Object detected2932
# Moving Object detected2934
# Moving Object detected2936
# Moving Object detected2938
# Moving Object detected2940
# Moving Object detected2942
# Moving Object detected2944
# Moving Object detected2946
# Moving Object detected2948
# Moving Object detected2950
# Moving Object detected2952
# Moving Object detected2954
# Moving Object detected2956
# Moving Object detected2958
# Moving Object detected2960
# Moving Object detected2962
# Moving Object detected2964
# Moving Object detected2966
# Moving Object detected2968
# Moving Object detected2970
# Moving Object detected2972
# Moving Object detected2974
# Moving Object detected2976
# Moving Object detected2978
# Moving Object detected2980
# Moving Object detected2982
# Moving Object detected2984
# Moving Object detected2986
# Moving Object detected2988
# Moving Object detected2990
# Moving Object detected2992
# Moving Object detected2994
# Moving Object detected2996
# Moving Object detected2998
# Moving Object detected3000
# Moving Object detected3002
# Moving Object detected3004
# Moving Object detected3006
# Moving Object detected3008
# Moving Object detected3010
# Moving Object detected3012
# Moving Object detected3014
# Moving Object detected3016
# Moving Object detected3018
# Moving Object detected3020
# Moving Object detected3022
# Moving Object detected3024
# Moving Object detected3026
# Moving Object detected3028
# Moving Object detected3030
# Moving Object detected3032
# Moving Object detected3034
# Moving Object detected3036
# Moving Object detected3038
# Moving Object detected3040
# Moving Object detected3042
# Moving Object detected3044
# Moving Object detected3046
# Moving Object detected3048
# Moving Object detected3050
# Moving Object detected3052
# Moving Object detected3054
# Moving Object detected3056
# Moving Object detected3058
# Moving Object detected3060
# Moving Object detected3062
# Moving Object detected3064
# Moving Object detected3066
# Moving Object detected3068
# Moving Object detected3070
# Moving Object detected3072
# Moving Object detected3074
# Moving Object detected3076
# Moving Object detected3078
# Moving Object detected3080
# Moving Object detected3082
# Moving Object detected3084
# Moving Object detected3086
# Moving Object detected3088
# Moving Object detected3090
# Moving Object detected3092
# Moving Object detected3094
# Moving Object detected3096
# Moving Object detected3098
# Moving Object detected3100
# Moving Object detected3102
# Moving Object detected3104
# Moving Object detected3106
# Moving Object detected3108
# Moving Object detected3110
# Moving Object detected3112
# Moving Object detected3114
# Moving Object detected3116
# Moving Object detected3118
# Moving Object detected3120
# Moving Object detected3122
# Moving Object detected3124
# Moving Object detected3126
# Moving Object detected3128
# Moving Object detected3130
# Moving Object detected3132
# Moving Object detected3134
# Moving Object detected3136
# Moving Object detected3138
# Moving Object detected3140
# Moving Object detected3142
# Moving Object detected3144
# Moving Object detected3146
# Moving Object detected3148
# Moving Object detected3150
# Moving Object detected3152
# Moving Object detected3154
# Moving Object detected3156
# Moving Object detected3158
# Moving Object detected3160
# Moving Object detected3162
# Moving Object detected3164
# Moving Object detected3166
# Moving Object detected3168
# Moving Object detected3170
# Moving Object detected3172
# Moving Object detected3174
# Moving Object detected3176
# Moving Object detected3178
# Moving Object detected3180
# Moving Object detected3182
# Moving Object detected3184
# Moving Object detected3186
# Moving Object detected3188
# Moving Object detected3190
# Moving Object detected3192
# Moving Object detected3194
# Moving Object detected3196
# Moving Object detected3198
# Moving Object detected3200
# Moving Object detected3202
# Moving Object detected3204
# Moving Object detected3206
# Moving Object detected3208
# Moving Object detected3210
# Moving Object detected3212
# Moving Object detected3214
# Moving Object detected3216
# Moving Object detected3218
# Moving Object detected3220
# Moving Object detected3222
# Moving Object detected3224
# Moving Object detected3226
# Moving Object detected3228
# Moving Object detected3230
# Moving Object detected3232
# Moving Object detected3234
# Moving Object detected3236
# Moving Object detected3238
# Moving Object detected3240
# Moving Object detected3242
# Moving Object detected3244
# Moving Object detected3246
# Moving Object detected3248
# Moving Object detected3250
# Moving Object detected3252
# Moving Object detected3254
# Moving Object detected3256
# Moving Object detected3258
# Moving Object detected3260
# Moving Object detected3262
# Moving Object detected3264
# Moving Object detected3266
# Moving Object detected3268
# Moving Object detected3270
# Moving Object detected3272
# Moving Object detected3274
# Moving Object detected3276
# Moving Object detected3278
# Moving Object detected3280
# Moving Object detected3282
# Moving Object detected3284
# Moving Object detected3286
# Moving Object detected3288
# Moving Object detected3290
# Moving Object detected3292
# Moving Object detected3294
# Moving Object detected3296
# Moving Object detected3298
# Moving Object detected3300
# Moving Object detected3302
# Moving Object detected3304
# Moving Object detected3306
# Moving Object detected3308
# Moving Object detected3310
# Moving Object detected3312
# Moving Object detected3314
# Moving Object detected3316
# Moving Object detected3318
# Moving Object detected3320
# Moving Object detected3322
# Moving Object detected3324
# Moving Object detected3326
# Moving Object detected3328
# Moving Object detected3330
# Moving Object detected3332
# Moving Object detected3334
# Moving Object detected3336
# Moving Object detected3338
# Moving Object detected3340
# Moving Object detected3342
# Moving Object detected3344
# Moving Object detected3346
# Moving Object detected3348
# Moving Object detected3350
# Moving Object detected3352
# Moving Object detected3354
# Moving Object detected3356
# Moving Object detected3358
# Moving Object detected3360
# Moving Object detected3362
# Moving Object detected3364
# Moving Object detected3366
# Moving Object detected3368
# Moving Object detected3370
# Moving Object detected3372
# Moving Object detected3374
# Moving Object detected3376
# Moving Object detected3378
# Moving Object detected3380
# Moving Object detected3382
# Moving Object detected3384
# Moving Object detected3386
# Moving Object detected3388
# Moving Object detected3390
# Moving Object detected3392
# Moving Object detected3394
# Moving Object detected3396
# Moving Object detected3398
# Moving Object detected3400
# Moving Object detected3402
# Moving Object detected3404
# Moving Object detected3406
# Moving Object detected3408
# Moving Object detected3410
# Moving Object detected3412
# Moving Object detected3414
# Moving Object detected3416
# Moving Object detected3418
# Moving Object detected3420
# Moving Object detected3422
# Moving Object detected3424
# Moving Object detected3426
# Moving Object detected3428
# Moving Object detected3430
# Moving Object detected3432
# Moving Object detected3434
# Moving Object detected3436
# Moving Object detected3438
# Moving Object detected3440
# Moving Object detected3442
# Moving Object detected3444
# Moving Object detected3446
# Moving Object detected3448
# Moving Object detected3450
# Moving Object detected3452
# Moving Object detected3454
# Moving Object detected3456
# Moving Object detected3458
# Moving Object detected3460
# Moving Object detected3462
# Moving Object detected3464
# Moving Object detected3466
# Moving Object detected3468
# Moving Object detected3470
# Moving Object detected3472
# Moving Object detected3474
# Moving Object detected3476
# Moving Object detected3478
# Moving Object detected3480
# Moving Object detected3482
# Moving Object detected3484
# Moving Object detected3486
# Moving Object detected3488
# Moving Object detected3490
# Moving Object detected3492
# Moving Object detected3494
# Moving Object detected3496
# Moving Object detected3498
# Moving Object detected3500
# Moving Object detected3502
# Moving Object detected3504
# Moving Object detected3506
# Moving Object detected3508
# Moving Object detected3510
# Moving Object detected3512
# Moving Object detected3514
# Moving Object detected3516
# Moving Object detected3518
# Moving Object detected3520
# Moving Object detected3522
# Moving Object detected3524
# Moving Object detected3526
# Moving Object detected3528
# Moving Object detected3530
# Moving Object detected3532
# Moving Object detected3534
# Moving Object detected3536
# Moving Object detected3538
# Moving Object detected3540
# Moving Object detected3542
# Moving Object detected3544
# Moving Object detected3546
# Moving Object detected3548
# Moving Object detected3550
# Moving Object detected3552
# Moving Object detected3554
# Moving Object detected3556
# Moving Object detected3558
# Moving Object detected3560
# Moving Object detected3562
# Moving Object detected3564
# Moving Object detected3566
# Moving Object detected3568
# Moving Object detected3570
# Moving Object detected3572
# Moving Object detected3574
# Moving Object detected3576
# Moving Object detected3578
# Moving Object detected3580
# Moving Object detected3582
# Moving Object detected3584
# Moving Object detected3586
# Moving Object detected3588
# Moving Object detected3590
# Moving Object detected3592
# Moving Object detected3594
# Moving Object detected3596
# Moving Object detected3598
# Moving Object detected3600
# Moving Object detected3602
# Moving Object detected3604
# Moving Object detected3606
# Moving Object detected3608
# Moving Object detected3610
# Moving Object detected3612
# Moving Object detected3614
# Moving Object detected3616
# Moving Object detected3618
# Moving Object detected3620
# Moving Object detected3622
# Moving Object detected3624
# Moving Object detected3626
# Moving Object detected3628
# Moving Object detected3630
# Moving Object detected3632
# Moving Object detected3634
# Moving Object detected3636
# Moving Object detected3638
# Moving Object detected3640
# Moving Object detected3642
# Moving Object detected3644
# Moving Object detected3646
# Moving Object detected3648
# Moving Object detected3650
# Moving Object detected3652
# Moving Object detected3654
# Moving Object detected3656
# Moving Object detected3658
# Moving Object detected3660
# Moving Object detected3662
# Moving Object detected3664
# Moving Object detected3666
# Moving Object detected3668
# Moving Object detected3670
# Moving Object detected3672
# Moving Object detected3674
# Moving Object detected3676
# Moving Object detected3678
# Moving Object detected3680
# Moving Object detected3682
# Moving Object detected3684
# Moving Object detected3686
# Moving Object detected3688
# Moving Object detected3690
# Moving Object detected3692
# Moving Object detected3694
# Moving Object detected3696
# Moving Object detected3698
# Moving Object detected3700
# Moving Object detected3702
# Moving Object detected3704
# Moving Object detected3706
# Moving Object detected3708
# Moving Object detected3710
# Moving Object detected3712
# Moving Object detected3714
# Moving Object detected3716
# Moving Object detected3718
# Moving Object detected3720
# Moving Object detected3722
# Moving Object detected3724
# Moving Object detected3726
# Moving Object detected3728
# Moving Object detected3730
# Moving Object detected3732
# Moving Object detected3734
# Moving Object detected3736
# Moving Object detected3738
# Moving Object detected3740
# Moving Object detected3742
# Moving Object detected3744
# Moving Object detected3746
# Moving Object detected3748
# Moving Object detected3750
# Moving Object detected3752
# Moving Object detected3754
# Moving Object detected3756
# Moving Object detected3758
# Moving Object detected3760
# Moving Object detected3762
# Moving Object detected3764
# Moving Object detected3766
# Moving Object detected3768
# Moving Object detected3770
# Moving Object detected3772
# Moving Object detected3774
# Moving Object detected3776
# Moving Object detected3778
# Moving Object detected3780
# Moving Object detected3782
# Moving Object detected3784
# Moving Object detected3786
# Moving Object detected3788
# Moving Object detected3790
# Moving Object detected3792
# Moving Object detected3794
# Moving Object detected3796
# Moving Object detected3798
# Moving Object detected3800
# Moving Object detected3802
# Moving Object detected3804
# Moving Object detected3806
# Moving Object detected3808
# Moving Object detected3810
# Moving Object detected3812
# Moving Object detected3814
# Moving Object detected3816
# Moving Object detected3818
# Moving Object detected3820
# Moving Object detected3822
# Moving Object detected3824
# Moving Object detected3826
# Moving Object detected3828
# Moving Object detected3830
# Moving Object detected3832
# Moving Object detected3834
# Moving Object detected3836
# Moving Object detected3838
# Moving Object detected3840
# Moving Object detected3842
# Moving Object detected3844
# Moving Object detected3846
# Moving Object detected3848
# Moving Object detected3850
# Moving Object detected3852
# Moving Object detected3854
# Moving Object detected3856
# Moving Object detected3858
# Moving Object detected3860
# Moving Object detected3862
# Moving Object detected3864
# Moving Object detected3866
# Moving Object detected3868
# Moving Object detected3870
# Moving Object detected3872
# Moving Object detected3874
# Moving Object detected3876
# Moving Object detected3878
# Moving Object detected3880
# Moving Object detected3882
# Moving Object detected3884
# Moving Object detected3886
# Moving Object detected3888
# Moving Object detected3890
# Moving Object detected3892
# Moving Object detected3894
# Moving Object detected3896
# Moving Object detected3898
# Moving Object detected3900
# Moving Object detected3902
# Moving Object detected3904
# Moving Object detected3906
# Moving Object detected3908
# Moving Object detected3910
# Moving Object detected3912
# Moving Object detected3914
# Moving Object detected3916
# Moving Object detected3918
# Moving Object detected3920
# Moving Object detected3922
# Moving Object detected3924
# Moving Object detected3926
# Moving Object detected3928
# Moving Object detected3930
# Moving Object detected3932
# Moving Object detected3934
# Moving Object detected3936
# Moving Object detected3938
# Moving Object detected3940
# Moving Object detected3942
# Moving Object detected3944
# Moving Object detected3946
# Moving Object detected3948
# Moving Object detected3950
# Moving Object detected3952
# Moving Object detected3954
# Moving Object detected3956
# Moving Object detected3958
# Moving Object detected3960
# Moving Object detected3962
# Moving Object detected3964
# Moving Object detected3966
# Moving Object detected3968
# Moving Object detected3970
# Moving Object detected3972
# Moving Object detected3974
# Moving Object detected3976
# Moving Object detected3978
# Moving Object detected3980
# Moving Object detected3982
# Moving Object detected3984
# Moving Object detected3986
# Moving Object detected3988
# Moving Object detected3990
# Moving Object detected3992
# Moving Object detected3994
# Moving Object detected3996
# Moving Object detected3998
# Moving Object detected4000
# Moving Object detected4002
# Moving Object detected4004
# Moving Object detected4006
# Moving Object detected4008
# Moving Object detected4010
# Moving Object detected4012
# Moving Object detected4014
# Moving Object detected4016
# Moving Object detected4018
# Moving Object detected4020
# Moving Object detected4022
# Moving Object detected4024
# Moving Object detected4026
# Moving Object detected4028
# Moving Object detected4030
# Moving Object detected4032
# Moving Object detected4034
# Moving Object detected4036
# Moving Object detected4038
# Moving Object detected4040
# Moving Object detected4042
# Moving Object detected4044
# Moving Object detected4046
# Moving Object detected4048
# Moving Object detected4050
# Moving Object detected4052
# Moving Object detected4054
# Moving Object detected4056
# Moving Object detected4058
# Moving Object detected4060
# Moving Object detected4062
# Moving Object detected4064
# Moving Object detected4066
# Moving Object detected4068
# Moving Object detected4070
# Moving Object detected4072
# Moving Object detected4074
# Moving Object detected4076
# Moving Object detected4078
# Moving Object detected4080
# Moving Object detected4082
# Moving Object detected4084
# Moving Object detected4086
# Moving Object detected4088
# Moving Object detected4090
# Moving Object detected4092
# Moving Object detected4094
# Moving Object detected4096
# Moving Object detected4098
# Moving Object detected4100
# Moving Object detected4102
# Moving Object detected4104
# Moving Object detected4106
# Moving Object detected4108
# Moving Object detected4110
# Moving Object detected4112
# Moving Object detected4114
# Moving Object detected4116
# Moving Object detected4118
# Moving Object detected4120
# Moving Object detected4122
# Moving Object detected4124
# Moving Object detected4126
# Moving Object detected4128
# Moving Object detected4130
# Moving Object detected4132
# Moving Object detected4134
# Moving Object detected4136
# Moving Object detected4138
# Moving Object detected4140
# Moving Object detected4142
# Moving Object detected4144
# Moving Object detected4146
# Moving Object detected4148
# Moving Object detected4150
# Moving Object detected4152
# Moving Object detected4154
# Moving Object detected4156
# Moving Object detected4158
# Moving Object detected4160
# Moving Object detected4162
# Moving Object detected4164
# Moving Object detected4166
# Moving Object detected4168
# Moving Object detected4170
# Moving Object detected4172
# Moving Object detected4174
# Moving Object detected4176
# Moving Object detected4178
# Moving Object detected4180
# Moving Object detected4182
# Moving Object detected4184
# Moving Object detected4186
# Moving Object detected4188
# Moving Object detected4190
# Moving Object detected4192
# Moving Object detected4194
# Moving Object detected4196
# Moving Object detected4198
# Moving Object detected4200
# Moving Object detected4202
# Moving Object detected4204
# Moving Object detected4206
# Moving Object detected4208
# Moving Object detected4210
# Moving Object detected4212
# Moving Object detected4214
# Moving Object detected4216
# Moving Object detected4218
# Moving Object detected4220
# Moving Object detected4222
# Moving Object detected4224
# Moving Object detected4226
# Moving Object detected4228
# Moving Object detected4230
# Moving Object detected4232
# Moving Object detected4234
# Moving Object detected4236
# Moving Object detected4238
# Moving Object detected4240
# Moving Object detected4242
# Moving Object detected4244
# Moving Object detected4246
# Moving Object detected4248
# Moving Object detected4250
# Moving Object detected4252
# Moving Object detected4254
# Moving Object detected4256
# Moving Object detected4258
# Moving Object detected4260
# Moving Object detected4262
# Moving Object detected4264
# Moving Object detected4266
# Moving Object detected4268
# Moving Object detected4270
# Moving Object detected4272
# Moving Object detected4274
# Moving Object detected4276
# Moving Object detected4278
# Moving Object detected4280
# Moving Object detected4282
# Moving Object detected4284
# Moving Object detected4286
# Moving Object detected4288
# Moving Object detected4290
# Moving Object detected4292
# Moving Object detected4294
# Moving Object detected4296
# Moving Object detected4298
# Moving Object detected4300
# Moving Object detected4302
# Moving Object detected4304
# Moving Object detected4306
# Moving Object detected4308
# Moving Object detected4310
# Moving Object detected4312
# Moving Object detected4314
# Moving Object detected4316
# Moving Object detected4318
# Moving Object detected4320
# Moving Object detected4322
# Moving Object detected4324
# Moving Object detected4326
# Moving Object detected4328
# Moving Object detected4330
# Moving Object detected4332
# Moving Object detected4334
# Moving Object detected4336
# Moving Object detected4338
# Moving Object detected4340
# Moving Object detected4342
# Moving Object detected4344
# Moving Object detected4346
# Moving Object detected4348
# Moving Object detected4350
# Moving Object detected4352
# Moving Object detected4354
# Moving Object detected4356
# Moving Object detected4358
# Moving Object detected4360
# Moving Object detected4362
# Moving Object detected4364
# Moving Object detected4366
# Moving Object detected4368
# Moving Object detected4370
# Moving Object detected4372
# Moving Object detected4374
# Moving Object detected4376
# Moving Object detected4378
# Moving Object detected4380
# Moving Object detected4382
# Moving Object detected4384
# Moving Object detected4386
# Moving Object detected4388
# Moving Object detected4390
# Moving Object detected4392
# Moving Object detected4394
# Moving Object detected4396
# Moving Object detected4398
# Moving Object detected4400
# Moving Object detected4402
# Moving Object detected4404
# Moving Object detected4406
# Moving Object detected4408
# Moving Object detected4410
# Moving Object detected4412
# Moving Object detected4414
# Moving Object detected4416
# Moving Object detected4418
# Moving Object detected4420
# Moving Object detected4422
# Moving Object detected4424
# Moving Object detected4426
# Moving Object detected4428
# Moving Object detected4430
# Moving Object detected4432
# Moving Object detected4434
# Moving Object detected4436
# Moving Object detected4438
# Moving Object detected4440
# Moving Object detected4442
# Moving Object detected4444
# Moving Object detected4446
# Moving Object detected4448
# Moving Object detected4450
# Moving Object detected4452
# Moving Object detected4454
# Moving Object detected4456
# Moving Object detected4458
# Moving Object detected4460
# Moving Object detected4462
# Moving Object detected4464
# Moving Object detected4466
# Moving Object detected4468
# Moving Object detected4470
# Moving Object detected4472
# Moving Object detected4474
# Moving Object detected4476
# Moving Object detected4478
# Moving Object detected4480
# Moving Object detected4482
# Moving Object detected4484
# Moving Object detected4486
# Moving Object detected4488
# Moving Object detected4490
# Moving Object detected4492
# Moving Object detected4494
# Moving Object detected4496
# Moving Object detected4498
# Moving Object detected4500
# Moving Object detected4502
# Moving Object detected4504
# Moving Object detected4506
# Moving Object detected4508
